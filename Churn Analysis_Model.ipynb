# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %%
df = pd.read_csv('/content/churn_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Monthly_Bill  Total_Usage_GB  Churn  Total_Charges  \
# 0           0         73.36             236      0        1247.12
# 1           1         48.76             172      0          48.76
# 2           2         85.47             460      0         427.35
# 3           3         97.94             297      1         293.82
# 4           4         58.14             266      0        1104.66
#
#    Senior_Citizen  Monthly_Usage_GB  Gender_Female  Gender_Male  \
# 0               1         13.882353              0            1
# 1               1        172.000000              1            0
# 2               0         92.000000              1            0
# 3               0         99.000000              1            0
# 4               0         14.000000              1            0
#
#    Location_Chicago  Location_Houston  Location_Los Angeles  Location_Miami  \
# 0                 0                 0                     1               0
# ...

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    Monthly_Bill  Total_Usage_GB  Churn  Total_Charges  Senior_Citizen  \
# 0         73.36             236      0        1247.12               1
# 1         48.76             172      0          48.76               1
# 2         85.47             460      0         427.35               0
# 3         97.94             297      1         293.82               0
# 4         58.14             266      0        1104.66               0
#
#    Monthly_Usage_GB  Gender_Female  Gender_Male  Location_Chicago  \
# 0         13.882353              0            1                 0
# 1        172.000000              1            0                 0
# 2         92.000000              1            0                 0
# 3         99.000000              1            0                 0
# 4         14.000000              1            0                 0
#
#    Location_Houston  Location_Los Angeles  Location_Miami  Location_New York  \
# ...

# %%
x = df.drop('Churn',axis=1)
y = df['Churn']

# %%
x.head()
# Out:
#    Monthly_Bill  Total_Usage_GB  Total_Charges  Senior_Citizen  \
# 0         73.36             236        1247.12               1
# 1         48.76             172          48.76               1
# 2         85.47             460         427.35               0
# 3         97.94             297         293.82               0
# 4         58.14             266        1104.66               0
#
#    Monthly_Usage_GB  Gender_Female  Gender_Male  Location_Chicago  \
# 0         13.882353              0            1                 0
# 1        172.000000              1            0                 0
# 2         92.000000              1            0                 0
# 3         99.000000              1            0                 0
# 4         14.000000              1            0                 0
#
#    Location_Houston  Location_Los Angeles  Location_Miami  Location_New York  \
# 0                 0                     1               0                  0
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Churn, dtype: int64

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
#Decision Tree Classifier
model_dt = DecisionTreeClassifier()

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model_dt.predict(x_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[5069, 4992],
#        [4934, 5005]])

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.5037

# %%
print(classification_report(y_test,y_pred,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51     10061
#            1       0.50      0.50      0.50      9939
#
#     accuracy                           0.50     20000
#    macro avg       0.50      0.50      0.50     20000
# weighted avg       0.50      0.50      0.50     20000

# %%
sm = SMOTEENN()

# %%
x_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train , xr_test, yr_train, yr_test = train_test_split(x_resampled,y_resampled,test_size=0.2)

# %%
model_dt_sm = DecisionTreeClassifier()

# %%
model_dt_sm.fit(xr_train,yr_train)
# Out:
# DecisionTreeClassifier()

# %%
yr_pred = model_dt_sm.predict(xr_test)

# %%
print(classification_report(yr_test,yr_pred,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63      1243
#            1       0.66      0.66      0.66      1339
#
#     accuracy                           0.65      2582
#    macro avg       0.65      0.65      0.65      2582
# weighted avg       0.65      0.65      0.65      2582

# %%
confusion_matrix(yr_test,yr_pred)
# Out:
# array([[785, 458],
#        [455, 884]])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier()

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = model_rf.predict(x_test)

# %%
print(classification_report(y_test,y_pred_rf,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50     10061
#            1       0.49      0.48      0.48      9939
#
#     accuracy                           0.49     20000
#    macro avg       0.49      0.49      0.49     20000
# weighted avg       0.49      0.49      0.49     20000

# %%
model_re_rf = RandomForestClassifier()

# %%
model_re_rf.fit(xr_train,yr_train)
# Out:
# RandomForestClassifier()

# %%
yr_pred_rf = model_re_rf.predict(xr_test)

# %%
print(classification_report(yr_test,yr_pred_rf,labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.58      0.57      1243
#            1       0.60      0.59      0.60      1339
#
#     accuracy                           0.59      2582
#    macro avg       0.59      0.59      0.59      2582
# weighted avg       0.59      0.59      0.59      2582

# %%
confusion_matrix(yr_test,yr_pred_rf)
# Out:
# array([[720, 523],
#        [547, 792]])

# %%
#Decision Tree More Better

# %%
model = keras.Sequential([
    keras.layers.Dense(18, input_shape=(18,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(xr_train, yr_train, epochs=20)
# Out:
# Epoch 1/20
# 323/323 [==============================] - 3s 3ms/step - loss: 2.0378 - accuracy: 0.4982
# Epoch 2/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.9067 - accuracy: 0.5075
# Epoch 3/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8511 - accuracy: 0.5005
# Epoch 4/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8556 - accuracy: 0.4974
# Epoch 5/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8242 - accuracy: 0.5033
# Epoch 6/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8298 - accuracy: 0.5013
# Epoch 7/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8112 - accuracy: 0.4950
# Epoch 8/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8250 - accuracy: 0.5066
# Epoch 9/20
# 323/323 [==============================] - 1s 2ms/step - loss: 0.8422 - accuracy: 0.5084
# Epoch 10/20
# ...

# %%
#Applying Hyperparameters tuning
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

grid_search = GridSearchCV(estimator=model_dt_sm, param_grid=param_grid, scoring='accuracy', cv=5)

grid_search.fit(xr_train, yr_train)

print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy: ", grid_search.best_score_)
# Out:
# Best Hyperparameters:  {'criterion': 'entropy', 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Accuracy:  0.6449735015669352

# %%
# Applying PCA
from sklearn.decomposition import PCA
pca = PCA(0.9)
xr_train_pca = pca.fit_transform(xr_train)
xr_test_pca = pca.transform(xr_test)
explained_variance = pca.explained_variance_ratio_

# %%
model_dt_PCA = DecisionTreeClassifier()

# %%
model_dt_PCA.fit(xr_train_pca,yr_train)
# Out:
# DecisionTreeClassifier()

# %%
yr_predict_pca = model_dt_PCA.predict(xr_test_pca)

# %%
model_score_r_pca = model_dt_PCA.score(xr_test_pca, yr_test)

# %%
print(model_score_r_pca)
print(metrics.classification_report(yr_test, yr_predict_pca))
# Out:
# 0.5333075135553834
#               precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52      1243
#            1       0.55      0.53      0.54      1339
#
#     accuracy                           0.53      2582
#    macro avg       0.53      0.53      0.53      2582
# weighted avg       0.53      0.53      0.53      2582

# %% [markdown]
# With PCA, we couldn't see any better results, hence let's finalise the model which was created by DT Classifier, and save the model so that we can use it in a later stage

# %%
from sklearn.ensemble import BaggingClassifier

# %%
import pickle

# %%
clf2 = BaggingClassifier(n_estimators=500, random_state=100)

# %%
clf2.fit(xr_train, yr_train)
# Out:
# BaggingClassifier(n_estimators=500, random_state=100)

# %%
xr_train_new = xr_train.sample(frac=0.1, random_state=42)
yr_train_new = yr_train[xr_train_new.index]

# %%
model.fit(xr_train_new, yr_train_new)
# Out:
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7794 - accuracy: 0.5237

# %%
predictions = clf2.predict(xr_test)

# %%
print(metrics.classification_report(yr_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      1243
#            1       0.74      0.74      0.74      1339
#
#     accuracy                           0.73      2582
#    macro avg       0.73      0.73      0.73      2582
# weighted avg       0.73      0.73      0.73      2582

# %%
filename = 'model1.sav'

# %% [markdown]
# ### MODEL WITH BEST ACCURACY IS BAGGING CLASSIFIER

# %%
pickle.dump(clf2,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename,'rb'))

# %%
loaded_model.score(xr_test,yr_test)
# Out:
# 0.7316034082106894
